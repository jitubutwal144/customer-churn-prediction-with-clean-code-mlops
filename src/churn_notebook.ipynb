# %%
import os
os.environ['QT_QPA_PLATFORM']='offscreen'
import shap
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()


from churn_library import *

# %%
# %load_ext autoreload
# %autoreload 2
from churn_library import *

# %% [markdown]
# # Import dataset

# %%
df = import_data("../data/raw/bank_data.csv")
df.head()
# Out:
#    Customer_Age Gender  Dependent_count Education_Level Marital_Status  \
# 0            45      M                3     High School        Married
# 1            49      F                5        Graduate         Single
# 2            51      M                3        Graduate        Married
# 3            40      F                4     High School        Unknown
# 4            40      M                3      Uneducated        Married
#
#   Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# 0     $60K - $80K          Blue              39                         5
# 1  Less than $40K          Blue              44                         6
# 2    $80K - $120K          Blue              36                         4
# 3  Less than $40K          Blue              34                         3
# 4     $60K - $80K          Blue              21                         5
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# ...

# %%
df.shape
# Out:
# (10127, 20)

# %%
df.dtypes
# Out:
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# Churn                         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# Churn                       0
# dtype: int64

# %%
df.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# ...

# %%
df.dtypes
# Out:
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# Churn                         int64
# dtype: object

# %%
df.select_dtypes(include='object').columns.to_list()
# Out:
# ['Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %% [markdown]
# # Perform Exploratory Data Analysis - EDA

# %%
perform_eda(df)
# Out:
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# savefig() got unexpected keyword argument "box_inches" which is no longer supported as of 3.3 and will become an error two minor releases later
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature engineering and preprocessing

# %%
# train test split
X_train, X_test, y_train, y_test = perform_feature_engineering(df, 'Churn')

# %%
X_train.head()
# Out:
#       Customer_Age  Dependent_count  Months_on_book  Total_Relationship_Count  \
# 415             49                2              38                         3
# 3749            61                0              51                         4
# 9295            27                0              19                         1
# 8290            52                1              36                         1
# 7672            44                3              36                         2
#
#       Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# 415                        2                      0        8077.0
# 3749                       2                      2        8476.0
# 9295                       1                      3       34516.0
# 8290                       1                      3        3040.0
# 7672                       3                      3        2228.0
#
#       Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# ...

# %%
X_train.dtypes
# Out:
# Customer_Age                  int64
# Dependent_count               int64
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# Gender_Churn                float64
# Education_Level_Churn       float64
# Marital_Status_Churn        float64
# Income_Category_Churn       float64
# Card_Category_Churn         float64
# dtype: object

# %% [markdown]
# # Train models

# %%
# This cell may take up to 15-20 minutes to run
train_models(X_train, X_test, y_train, y_test)

# %%
# Load trained models
rfc_model = joblib.load('./models/rfc_model.pkl')
lr_model = joblib.load('./models/logistic_model.pkl')

# %% [markdown]
# # Analyze feature importances

# %%
explainer = shap.TreeExplainer(rfc_model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_train, plot_type="bar",show=False)
plt.savefig('./images/SHAP/SHAP.png')

# %%
# Summary plot for Class = 1 (churned)
shap.summary_plot(shap_values[1], X_test, show=False)
plt.savefig('./images/SHAP/summary_shap.png')

# %%
results_path = "./images/results"
feature_importance_plot(rfc_model, X_train, 'Random_Forest',results_path)
